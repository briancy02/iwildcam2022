# %% [markdown]
# # One time tasks

# %%
# == Download the repo content and install dependencies ==
# !git clone https://github.com/ifzhang/ByteTrack.git

# %mkdir pretrained
# %cd pretrained

# == Download pretrained X model weights ==
# Out:
# Cloning into 'ByteTrack'...
# remote: Enumerating objects: 1926, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 1926 (delta 0), reused 2 (delta 0), pack-reused 1921
# Receiving objects: 100% (1926/1926), 78.16 MiB | 19.12 MiB/s, done.
# Resolving deltas: 100% (1091/1091), done.
# Checking out files: 100% (212/212), done.
# mkdir: cannot create directory ‘pretrained’: File exists
# /content/drive/MyDrive/iwildcam2022/pretrained

# %%
# %mkdir pretrained

# %%
# %cd pretrained
# !gdown --id "1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5"
# Out:
# [Errno 2] No such file or directory: 'pretrained'
# /home/briancy2/iwildcam2022/pretrained
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5
# To: /home/briancy2/iwildcam2022/pretrained/bytetrack_x_mot17.pth.tar
# 100%|████████████████████████████████████████| 793M/793M [00:12<00:00, 62.7MB/s]

# %% [markdown]
# # Regulars

# %%
# %cd bytetrack
# Out:
# /home/briancy2/iwildcam2022/bytetrack

# %%
# !pip install thop
# !pip install lap
# Out:
# Requirement already satisfied: thop in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (0.0.31.post2005241907)
# Requirement already satisfied: torch>=1.0.0 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from thop) (1.10.1)
# Requirement already satisfied: typing_extensions in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from torch>=1.0.0->thop) (3.7.4.3)
# Requirement already satisfied: lap in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (0.4.0)

# %%
# !python3 tools/convert_mot17_to_coco.py
# Out:
# MOT17-02-FRCNN: 600 images
# 600 ann images
# 42 73
# MOT17-04-FRCNN: 1050 images
# 1050 ann images
# 104 140
# MOT17-05-FRCNN: 837 images
# 837 ann images
# 172 152
# MOT17-09-FRCNN: 525 images
# 525 ann images
# 189 43
# MOT17-10-FRCNN: 654 images
# 654 ann images
# 233 71
# MOT17-11-FRCNN: 900 images
# 900 ann images
# 274 89
# MOT17-13-FRCNN: 750 images
# 750 ann images
# 359 170
# loaded train_half for 2664 images and 58407 samples
# MOT17-02-FRCNN: 600 images
# 600 ann images
# 53 83
# MOT17-04-FRCNN: 1050 images
# 1050 ann images
# 122 141
# MOT17-05-FRCNN: 837 images
# 837 ann images
# 193 156
# MOT17-09-FRCNN: 525 images
# 525 ann images
# 215 29
# MOT17-10-FRCNN: 654 images
# 654 ann images
# 251 73
# MOT17-11-FRCNN: 900 images
# 900 ann images
# 295 91
# MOT17-13-FRCNN: 750 images
# 750 ann images
# 339 165
# loaded val_half for 2652 images and 53890 samples
# MOT17-02-FRCNN: 600 images
# 600 ann images
# 62 83
# MOT17-04-FRCNN: 1050 images
# 1050 ann images
# 145 141
# MOT17-05-FRCNN: 837 images
# 837 ann images
# 278 156
# MOT17-09-FRCNN: 525 images
# 525 ann images
# 304 43
# MOT17-10-FRCNN: 654 images
# 654 ann images
# 361 73
# MOT17-11-FRCNN: 900 images
# 900 ann images
# 436 91
# MOT17-13-FRCNN: 750 images
# 750 ann images
# 546 170
# loaded train for 5316 images and 112297 samples
# MOT17-01-DPM: 450 images
# 0 -1
# MOT17-01-FRCNN: 450 images
# 0 -1
# MOT17-01-SDP: 450 images
# 0 -1
# MOT17-03-DPM: 1500 images
# 0 -1
# MOT17-03-FRCNN: 1500 images
# 0 -1
# MOT17-03-SDP: 1500 images
# 0 -1
# MOT17-06-DPM: 1194 images
# 0 -1
# MOT17-06-FRCNN: 1194 images
# 0 -1
# MOT17-06-SDP: 1194 images
# 0 -1
# MOT17-07-DPM: 500 images
# 0 -1
# MOT17-07-FRCNN: 500 images
# 0 -1
# MOT17-07-SDP: 500 images
# 0 -1
# MOT17-08-DPM: 625 images
# 0 -1
# MOT17-08-FRCNN: 625 images
# 0 -1
# MOT17-08-SDP: 625 images
# 0 -1
# MOT17-12-DPM: 900 images
# 0 -1
# MOT17-12-FRCNN: 900 images
# 0 -1
# MOT17-12-SDP: 900 images
# 0 -1
# MOT17-14-DPM: 750 images
# 0 -1
# MOT17-14-FRCNN: 750 images
# 0 -1
# MOT17-14-SDP: 750 images
# 0 -1
# loaded test for 17757 images and 0 samples

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.20.3)
# Requirement already satisfied: torch>=1.7 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.10.1)
# Collecting opencv_python
#   Using cached opencv-python-4.5.5.64.tar.gz (89.9 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: loguru in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.6.0)
# Collecting scikit-image
#   Using cached scikit-image-0.19.2.tar.gz (22.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.64.0)
# Requirement already satisfied: torchvision>=0.10.0 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.11.2)
# Requirement already satisfied: Pillow in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (8.4.0)
# Requirement already satisfied: thop in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.0.31.post2005241907)
# Collecting ninja
#   Using cached ninja-1.10.2.3-py2.py3-none-manylinux_2_17_ppc64le.manylinux2014_ppc64le.whl (148 kB)
# Requirement already satisfied: tabulate in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.8.9)
# Requirement already satisfied: tensorboard in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (2.7.0)
# Requirement already satisfied: lap in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: motmetrics in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (1.2.5)
# Requirement already satisfied: filterpy in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.4.5)
# Requirement already satisfied: h5py in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (3.2.1)
# Collecting onnx==1.8.1
#   Using cached onnx-1.8.1.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.8.0 (from versions: none)
# ERROR: No matching distribution found for onnxruntime==1.8.0

# %%
# == Install ByteTrack ==
# !python3 setup.py develop
# Out:
# running develop
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/setuptools/command/easy_install.py:160: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# writing yolox.egg-info/PKG-INFO
# writing dependency_links to yolox.egg-info/dependency_links.txt
# writing top-level names to yolox.egg-info/top_level.txt
# package init file 'YOLOX_outputs/__init__.py' not found (or not a regular file)
# package init file 'datasets/__init__.py' not found (or not a regular file)
# package init file 'videos/__init__.py' not found (or not a regular file)
# package init file 'tools/__init__.py' not found (or not a regular file)
# package init file 'tutorials/__init__.py' not found (or not a regular file)
# package init file 'exps/__init__.py' not found (or not a regular file)
# package init file 'assets/__init__.py' not found (or not a regular file)
# package init file 'pretrained/__init__.py' not found (or not a regular file)
# package init file 'deploy/__init__.py' not found (or not a regular file)
# package init file 'build/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_vis/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_results/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_06_26_19/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_06_32_45/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_06_33_26/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_05_35_18/__init__.py' not found (or not a regular file)
# package init file 'datasets/data_path/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/MOT17/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/annotations/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/results/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-09-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-02-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-05-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-13-SDP/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-11-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-10-DPM/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/train/MOT17-04-FRCNN/gt/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-FRCNN/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-SDP/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-DPM/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-01-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-07-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-06-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-14-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-FRCNN/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-FRCNN/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-08-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-SDP/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-12-SDP/det/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-DPM/img1/__init__.py' not found (or not a regular file)
# package init file 'datasets/mot/test/MOT17-03-DPM/det/__init__.py' not found (or not a regular file)
# package init file 'tutorials/motr/__init__.py' not found (or not a regular file)
# package init file 'tutorials/transtrack/__init__.py' not found (or not a regular file)
# package init file 'tutorials/trades/__init__.py' not found (or not a regular file)
# package init file 'tutorials/jde/__init__.py' not found (or not a regular file)
# package init file 'tutorials/ctracker/__init__.py' not found (or not a regular file)
# package init file 'tutorials/qdtrack/__init__.py' not found (or not a regular file)
# package init file 'tutorials/cstrack/__init__.py' not found (or not a regular file)
# package init file 'tutorials/fairmot/__init__.py' not found (or not a regular file)
# package init file 'tutorials/centertrack/__init__.py' not found (or not a regular file)
# package init file 'tutorials/motr/mot_online/__init__.py' not found (or not a regular file)
# package init file 'tutorials/transtrack/mot_online/__init__.py' not found (or not a regular file)
# package init file 'tutorials/trades/mot_online/__init__.py' not found (or not a regular file)
# package init file 'tutorials/ctracker/mot_online/__init__.py' not found (or not a regular file)
# package init file 'tutorials/qdtrack/mot_online/__init__.py' not found (or not a regular file)
# package init file 'tutorials/centertrack/mot_online/__init__.py' not found (or not a regular file)
# package init file 'yolox/tracker/__init__.py' not found (or not a regular file)
# package init file 'yolox/deepsort_tracker/__init__.py' not found (or not a regular file)
# package init file 'yolox/sort_tracker/__init__.py' not found (or not a regular file)
# package init file 'yolox/tracking_utils/__init__.py' not found (or not a regular file)
# package init file 'yolox/motdt_tracker/__init__.py' not found (or not a regular file)
# package init file 'yolox/layers/csrc/__init__.py' not found (or not a regular file)
# package init file 'yolox/layers/csrc/cocoeval/__init__.py' not found (or not a regular file)
# package init file 'exps/example/__init__.py' not found (or not a regular file)
# package init file 'exps/default/__init__.py' not found (or not a regular file)
# package init file 'exps/example/mot/__init__.py' not found (or not a regular file)
# package init file 'deploy/ncnn/__init__.py' not found (or not a regular file)
# package init file 'deploy/ONNXRuntime/__init__.py' not found (or not a regular file)
# package init file 'deploy/TensorRT/__init__.py' not found (or not a regular file)
# package init file 'deploy/ncnn/cpp/__init__.py' not found (or not a regular file)
# package init file 'deploy/ncnn/cpp/include/__init__.py' not found (or not a regular file)
# package init file 'deploy/ncnn/cpp/src/__init__.py' not found (or not a regular file)
# package init file 'deploy/TensorRT/cpp/__init__.py' not found (or not a regular file)
# package init file 'deploy/TensorRT/python/__init__.py' not found (or not a regular file)
# package init file 'deploy/TensorRT/cpp/include/__init__.py' not found (or not a regular file)
# package init file 'deploy/TensorRT/cpp/src/__init__.py' not found (or not a regular file)
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'yolox.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'yolox.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-ppc64le-3.9/yolox/_C.cpython-39-powerpc64le-linux-gnu.so -> yolox
# Creating /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/yolox.egg-link (link to .)
# yolox 0.1.0 is already the active version in easy-install.pth
#
# Installed /home/briancy2/iwildcam2022/bytetrack
# Processing dependencies for yolox==0.1.0
# Finished processing dependencies for yolox==0.1.0

# %%
# run inference demo (can be slow on colab). The cell output is deflected to the file 'log.txt' for downstream use to display the result but feel free to remove 
# !python3 tools/demo_track.py video -f exps/example/mot/yolox_x_mix_det.py -c pretrained/bytetrack_x_mot17.pth.tar --fp16 --fuse --save_result &> log.txt

# %%
# !python3 tools/demo_track.py video --path='-f exps/example/mot/yolox_x_mix_det.py -c pretrained/bytetrack_x_mot17.pth.tar --fp16 --fuse --save_result &> log.txt

# %%
# !pip install filterpy
# Out:
# Collecting filterpy
#   Using cached filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from filterpy) (1.20.3)
# Requirement already satisfied: scipy in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from filterpy) (1.7.3)
# Requirement already satisfied: matplotlib in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from filterpy) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from matplotlib->filterpy) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from matplotlib->filterpy) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from matplotlib->filterpy) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from matplotlib->filterpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from matplotlib->filterpy) (1.4.2)
# Requirement already satisfied: six>=1.5 in /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.15.0)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=de5d7fc56ca80969d8acde4f45e71076f191c282477798c4c9acfdcd203deb44
#   Stored in directory: /home/briancy2/.cache/pip/wheels/53/e6/de/a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built filterpy
# Installing collected packages: filterpy
# Successfully installed filterpy-1.4.5

# %%
# !python3 tools/track.py -f exps/example/mot/yolox_x_mix_det.py -c pretrained/bytetrack_x_mot17.pth.tar -b 1 -d 1 --fp16 --fuse
# !python3 tools/interpolation.py
# Out:
# 2022-05-03 12:10:16 | INFO     | __main__:154 - Args: Namespace(experiment_name='yolox_x_mix_det', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_mix_det.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_x_mot17.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.9, min_box_area=100, mot20=False)
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /scratch/env/opence1.5.1/conda-bld/pytorch-base_1643072044833/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2022-05-03 12:10:24 | INFO     | __main__:164 - Model Summary: Params: 99.00M, Gflops: 791.73
# 2022-05-03 12:10:24 | INFO     | yolox.data.datasets.mot:39 - loading annotations into memory...
# 2022-05-03 12:10:24 | INFO     | yolox.data.datasets.mot:39 - Done (t=0.12s)
# 2022-05-03 12:10:24 | INFO     | pycocotools.coco:88 - creating index...
# 2022-05-03 12:10:24 | INFO     | pycocotools.coco:88 - index created!
# 2022-05-03 12:10:27 | INFO     | __main__:186 - loading checkpoint
# 2022-05-03 12:10:28 | INFO     | __main__:191 - loaded checkpoint done.
# 2022-05-03 12:10:28 | INFO     | __main__:197 - 	Fusing model...
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/torch/_tensor.py:1013: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at  /scratch/env/opence1.5.1/conda-bld/pytorch-base_1643072044833/work/build/aten/src/ATen/core/TensorBody.h:417.)
#   return self._grad
#   3%|2         | 449/17757 [00:27<16:38, 17.33it/s] 2022-05-03 12:10:57 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-DPM.txt
#   5%|5         | 900/17757 [00:50<14:58, 18.76it/s]2022-05-03 12:11:21 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-FRCNN.txt
#   8%|7         | 1350/17757 [01:15<12:24, 22.05it/s]2022-05-03 12:11:45 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-SDP.txt
#  16%|#6        | 2849/17757 [02:48<13:42, 18.12it/s]2022-05-03 12:13:24 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-03-DPM.txt
#  24%|##4       | 4349/17757 [04:33<15:22, 14.54it/s]  2022-05-03 12:15:09 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-03-FRCNN.txt
#  33%|###2      | 5849/17757 [06:21<11:22, 17.45it/s]  2022-05-03 12:16:58 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-03-SDP.txt
#  40%|###9      | 7043/17757 [07:24<08:43, 20.47it/s]  2022-05-03 12:17:55 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-06-DPM.txt
#  46%|####6     | 8238/17757 [08:20<08:27, 18.75it/s]2022-05-03 12:18:51 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-06-FRCNN.txt
#  53%|#####3    | 9431/17757 [09:20<07:31, 18.45it/s]2022-05-03 12:19:51 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-06-SDP.txt
#  56%|#####5    | 9931/17757 [09:50<06:53, 18.92it/s]2022-05-03 12:20:21 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-07-DPM.txt
#  59%|#####8    | 10432/17757 [10:19<07:39, 15.95it/s]2022-05-03 12:20:50 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-07-FRCNN.txt
#  62%|######1   | 10931/17757 [10:50<06:41, 16.99it/s]2022-05-03 12:21:21 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-07-SDP.txt
#  65%|######5   | 11556/17757 [11:26<06:24, 16.13it/s]2022-05-03 12:21:57 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-08-DPM.txt
#  69%|######8   | 12182/17757 [12:03<05:59, 15.53it/s]2022-05-03 12:22:35 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-08-FRCNN.txt
#  72%|#######2  | 12806/17757 [12:42<04:19, 19.04it/s]2022-05-03 12:23:13 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-08-SDP.txt
#  77%|#######7  | 13706/17757 [13:29<03:28, 19.40it/s]2022-05-03 12:23:59 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-12-DPM.txt
#  82%|########2 | 14607/17757 [14:19<03:09, 16.65it/s]2022-05-03 12:24:50 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-12-FRCNN.txt
#  87%|########7 | 15507/17757 [15:11<02:01, 18.51it/s]2022-05-03 12:25:41 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-12-SDP.txt
#  92%|#########1| 16257/17757 [15:56<01:29, 16.67it/s]2022-05-03 12:26:27 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-14-DPM.txt
#  96%|#########5| 17006/17757 [16:40<00:41, 17.96it/s]2022-05-03 12:27:11 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-14-FRCNN.txt
# 100%|#########9| 17756/17757 [17:22<00:00, 21.28it/s]2022-05-03 12:27:53 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-14-SDP.txt
# 100%|##########| 17757/17757 [17:23<00:00, 17.02it/s]
# 2022-05-03 12:27:53 | INFO     | yolox.evaluators.mot_evaluator:628 - Evaluate in main process...
# 2022-05-03 12:28:10 | INFO     | yolox.evaluators.mot_evaluator:657 - Loading and preparing results...
# 2022-05-03 12:28:15 | INFO     | yolox.evaluators.mot_evaluator:657 - DONE (t=5.10s)
# 2022-05-03 12:28:15 | INFO     | pycocotools.coco:363 - creating index...
# 2022-05-03 12:28:16 | INFO     | pycocotools.coco:363 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 4.66 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.45 seconds.
# gt_type
# 2022-05-03 12:28:22 | INFO     | __main__:218 -
# Average forward time: 38.30 ms, Average track time: 10.55 ms, Average inference time: 48.85 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#
# gt_files ['datasets/mot/train/MOT17-11-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-04-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-09-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-09-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-09-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-10-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-02-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-05-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-11-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-13-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-02-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-04-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-05-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-10-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-02-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-05-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-13-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-13-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-11-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-10-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-04-FRCNN/gt/gt.txt']
# 2022-05-03 12:28:22 | INFO     | __main__:235 - Found 21 groundtruths and 21 test files.
# 2022-05-03 12:28:22 | INFO     | __main__:236 - Available LAP solvers ['lap', 'scipy']
# 2022-05-03 12:28:22 | INFO     | __main__:237 - Default LAP solver 'lap'
# 2022-05-03 12:28:22 | INFO     | __main__:238 - Loading files.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-08-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-12-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-12-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-01-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-12-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-06-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-03-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-03-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-07-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-14-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-07-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-06-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-08-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-01-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-06-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-14-DPM, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-01-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-07-SDP, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-14-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-03-FRCNN, skipping.
# 2022-05-03 12:28:42 | WARNING  | __main__:122 - No ground truth for MOT17-08-FRCNN, skipping.
# 2022-05-03 12:28:42 | INFO     | __main__:246 - Running metrics
#         Rcll Prcn GT  MT  PT  ML  FP  FN IDs  FM MOTA MOTP num_objects
# OVERALL  NaN  NaN  0 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN           0
#         IDF1 IDP IDR Rcll Prcn GT MT PT ML FP FN IDs  FM MOTA MOTP IDt IDa IDm num_objects
# OVERALL  NaN NaN NaN  NaN  NaN  0  0  0  0  0  0   0   0  NaN  NaN   0   0   0           0
# 2022-05-03 12:28:42 | INFO     | __main__:271 - Completed
# Traceback (most recent call last):
#   File "/home/briancy2/iwildcam2022/bytetrack/tools/interpolation.py", line 122, in <module>
#     mkdir_if_missing(save_path)
#   File "/home/briancy2/iwildcam2022/bytetrack/tools/interpolation.py", line 11, in mkdir_if_missing
#     os.makedirs(d)
#   File "/home/briancy2/.conda/envs/iwildcam/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/briancy2/.conda/envs/iwildcam/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/briancy2/.conda/envs/iwildcam/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   [Previous line repeated 2 more times]
#   File "/home/briancy2/.conda/envs/iwildcam/lib/python3.9/os.py", line 225, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/opt/tiger'

# %%
# !pip3 install cython
# !pip3 install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip3 install cython_bbox
# !pip3 install -r requirements.txt

# %%
# !python3 tools/train.py -f exps/example/mot/yolox_x_mix_det.py -d 1 -b 48 --fp16 -o -c pretrained/yolox_x.pth
# Out:
# 2022-05-03 12:41:34 | INFO     | yolox.core.trainer:124 - args: Namespace(experiment_name='yolox_x_mix_det', name=None, dist_backend='nccl', dist_url=None, batch_size=48, devices=1, local_rank=0, exp_file='exps/example/mot/yolox_x_mix_det.py', resume=False, ckpt='pretrained/yolox_x.pth', start_epoch=None, num_machines=1, machine_rank=0, fp16=True, occupy=True, opts=[])
# 2022-05-03 12:41:34 | INFO     | yolox.core.trainer:125 - exp value:
# ╒══════════════════╤═══════════════════╕
# │ keys             │ values            │
# ╞══════════════════╪═══════════════════╡
# │ seed             │ None              │
# ├──────────────────┼───────────────────┤
# │ output_dir       │ './YOLOX_outputs' │
# ├──────────────────┼───────────────────┤
# │ print_interval   │ 20                │
# ├──────────────────┼───────────────────┤
# │ eval_interval    │ 5                 │
# ├──────────────────┼───────────────────┤
# │ num_classes      │ 1                 │
# ├──────────────────┼───────────────────┤
# │ depth            │ 1.33              │
# ├──────────────────┼───────────────────┤
# │ width            │ 1.25              │
# ├──────────────────┼───────────────────┤
# │ data_num_workers │ 4                 │
# ├──────────────────┼───────────────────┤
# │ input_size       │ (800, 1440)       │
# ├──────────────────┼───────────────────┤
# │ random_size      │ (18, 32)          │
# ├──────────────────┼───────────────────┤
# │ train_ann        │ 'train.json'      │
# ├──────────────────┼───────────────────┤
# │ val_ann          │ 'test.json'       │
# ├──────────────────┼───────────────────┤
# │ degrees          │ 10.0              │
# ├──────────────────┼───────────────────┤
# │ translate        │ 0.1               │
# ├──────────────────┼───────────────────┤
# │ scale            │ (0.1, 2)          │
# ├──────────────────┼───────────────────┤
# │ mscale           │ (0.8, 1.6)        │
# ├──────────────────┼───────────────────┤
# │ shear            │ 2.0               │
# ├──────────────────┼───────────────────┤
# │ perspective      │ 0.0               │
# ├──────────────────┼───────────────────┤
# │ enable_mixup     │ True              │
# ├──────────────────┼───────────────────┤
# │ warmup_epochs    │ 1                 │
# ├──────────────────┼───────────────────┤
# │ max_epoch        │ 80                │
# ├──────────────────┼───────────────────┤
# │ warmup_lr        │ 0                 │
# ├──────────────────┼───────────────────┤
# │ basic_lr_per_img │ 1.5625e-05        │
# ├──────────────────┼───────────────────┤
# │ scheduler        │ 'yoloxwarmcos'    │
# ├──────────────────┼───────────────────┤
# │ no_aug_epochs    │ 10                │
# ├──────────────────┼───────────────────┤
# │ min_lr_ratio     │ 0.05              │
# ├──────────────────┼───────────────────┤
# │ ema              │ True              │
# ├──────────────────┼───────────────────┤
# │ weight_decay     │ 0.0005            │
# ├──────────────────┼───────────────────┤
# │ momentum         │ 0.9               │
# ├──────────────────┼───────────────────┤
# │ exp_name         │ 'yolox_x_mix_det' │
# ├──────────────────┼───────────────────┤
# │ test_size        │ (800, 1440)       │
# ├──────────────────┼───────────────────┤
# │ test_conf        │ 0.001             │
# ├──────────────────┼───────────────────┤
# │ nmsthre          │ 0.7               │
# ╘══════════════════╧═══════════════════╛
# /home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /scratch/env/opence1.5.1/conda-bld/pytorch-base_1643072044833/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2022-05-03 12:41:38 | INFO     | yolox.core.trainer:130 - Model Summary: Params: 99.00M, Gflops: 791.73
# 2022-05-03 12:41:39 | INFO     | yolox.core.trainer:289 - loading checkpoint for fine tuning
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.0.weight in checkpoint is torch.Size([80, 320, 1, 1]), while shape of head.cls_preds.0.weight in model is torch.Size([1, 320, 1, 1]).
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.0.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.0.bias in model is torch.Size([1]).
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.1.weight in checkpoint is torch.Size([80, 320, 1, 1]), while shape of head.cls_preds.1.weight in model is torch.Size([1, 320, 1, 1]).
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.1.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.1.bias in model is torch.Size([1]).
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.2.weight in checkpoint is torch.Size([80, 320, 1, 1]), while shape of head.cls_preds.2.weight in model is torch.Size([1, 320, 1, 1]).
# 2022-05-03 12:41:41 | WARNING  | yolox.utils.checkpoint:25 - Shape of head.cls_preds.2.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.2.bias in model is torch.Size([1]).
# 2022-05-03 12:41:41 | INFO     | yolox.data.datasets.mot:39 - loading annotations into memory...
# 2022-05-03 12:41:41 | ERROR    | yolox.core.launch:90 - An error has been caught in function 'launch', process 'MainProcess' (730845), thread 'MainThread' (140736303483424):
# Traceback (most recent call last):
#
#   File "/home/briancy2/iwildcam2022/bytetrack/tools/train.py", line 114, in <module>
#     launch(
#     └ <function launch at 0x7ffe2680c310>
#
# > File "/home/briancy2/iwildcam2022/bytetrack/yolox/core/launch.py", line 90, in launch
#     main_func(*args)
#     │          └ (╒══════════════════╤════════════════════════════════════════════════════════════════════════════════════════════════════════...
#     └ <function main at 0x7ffe24a15f70>
#
#   File "/home/briancy2/iwildcam2022/bytetrack/tools/train.py", line 100, in main
#     trainer.train()
#     │       └ <function Trainer.train at 0x7ffe2641d280>
#     └ <yolox.core.trainer.Trainer object at 0x7ffe24a1d5e0>
#
#   File "/home/briancy2/iwildcam2022/bytetrack/yolox/core/trainer.py", line 70, in train
#     self.before_train()
#     │    └ <function Trainer.before_train at 0x7ffe249fe5e0>
#     └ <yolox.core.trainer.Trainer object at 0x7ffe24a1d5e0>
#
#   File "/home/briancy2/iwildcam2022/bytetrack/yolox/core/trainer.py", line 143, in before_train
#     self.train_loader = self.exp.get_data_loader(
#     │                   │    │   └ <function Exp.get_data_loader at 0x7ffe24a18c10>
#     │                   │    └ ╒══════════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════...
#     │                   └ <yolox.core.trainer.Trainer object at 0x7ffe24a1d5e0>
#     └ <yolox.core.trainer.Trainer object at 0x7ffe24a1d5e0>
#
#   File "/home/briancy2/iwildcam2022/bytetrack/exps/example/mot/yolox_x_mix_det.py", line 42, in get_data_loader
#     dataset = MOTDataset(
#               └ <class 'yolox.data.datasets.mot.MOTDataset'>
#
#   File "/home/briancy2/iwildcam2022/bytetrack/yolox/data/datasets/mot.py", line 39, in __init__
#     self.coco = COCO(os.path.join(self.data_dir, "annotations", self.json_file))
#     │           │    │  │    │    │    │                        │    └ 'train.json'
#     │           │    │  │    │    │    │                        └ <yolox.data.datasets.mot.MOTDataset object at 0x7ffdd00f90a0>
#     │           │    │  │    │    │    └ '/home/briancy2/iwildcam2022/bytetrack/datasets/mix_det'
#     │           │    │  │    │    └ <yolox.data.datasets.mot.MOTDataset object at 0x7ffdd00f90a0>
#     │           │    │  │    └ <function join at 0x7fffb8fb50d0>
#     │           │    │  └ <module 'posixpath' from '/home/briancy2/.conda/envs/iwildcam/lib/python3.9/posixpath.py'>
#     │           │    └ <module 'os' from '/home/briancy2/.conda/envs/iwildcam/lib/python3.9/os.py'>
#     │           └ <class 'pycocotools.coco.COCO'>
#     └ <yolox.data.datasets.mot.MOTDataset object at 0x7ffdd00f90a0>
#
#   File "/home/briancy2/.conda/envs/iwildcam/lib/python3.9/site-packages/pycocotools/coco.py", line 84, in __init__
#     dataset = json.load(open(annotation_file, 'r'))
#               │    │         └ '/home/briancy2/iwildcam2022/bytetrack/datasets/mix_det/annotations/train.json'
#               │    └ <function load at 0x7fffb829e1f0>
#               └ <module 'json' from '/home/briancy2/.conda/envs/iwildcam/lib/python3.9/json/__init__.py'>
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/briancy2/iwildcam2022/bytetrack/datasets/mix_det/annotations/train.json'

# %%
# !python3 tools/track.py -f exps/example/mot/yolox_x_mix_det.py -c pretrained/bytetrack_x_mot17.pth.tar -b 1 -d 1 --fp16 --fuse
# !python3 tools/interpolation.py

# %%
# !gdown "https://drive.google.com/uc?id=134QOvaatwKdy0iIeNqA_p-xkAhkV4F8Y&confirm=t"
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=134QOvaatwKdy0iIeNqA_p-xkAhkV4F8Y&confirm=t

# %%
# !pwd
# Out:
# --2022-05-03 12:52:49--  https://docs.google.com/uc?export=download&confirm=&id=134QOvaatwKdy0iIeNqA_p-xkAhkV4F8Y
# Resolving docs.google.com (docs.google.com)... 142.250.190.78, 2607:f8b0:4009:80a::200e
# Connecting to docs.google.com (docs.google.com)|142.250.190.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘FILENAME’
#
# FILENAME                [ <=>                ]   1.95K  --.-KB/s    in 0.001s
#
# 2022-05-03 12:52:49 (2.23 MB/s) - ‘FILENAME’ saved [1993]

# %%
import cv2 as cv
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_3199054/1332463745.py in <cell line: 2>()
#       1 import cv2 as cv
# ----> 2 cv2.waitKey()
#
# error: OpenCV(4.5.3) ../modules/highgui/src/window.cpp:1340: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvWaitKey'

# %%
# !pwd
# Out:
# /home/briancy2/iwildcam2022/bytetrack

# %%
# == Get rendered result video file path ==
import re
with open('log.txt', 'r') as file:
    text = file.read().replace('\n', '')

m = re.search('video save_path is ./(.+?).mp4', text)
found = None
if m:
    found =  m.group(1) + ".mp4"
found
# Out:
# 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_06_33_26/palace.mp4'

# %%
# == Convert mp4 to webm video file for proper display on colab ==
# !ffmpeg -i $found -vcodec vp9 out.webm -y
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/root/worker/containers/00002vr438k/tmp/build/80754af9/ffmpeg_1587154189351/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_pl --cc=/root/worker/containers/00002vr438k/tmp/build/80754af9/ffmpeg_1587154189351/_build_env/bin/powerpc64le-conda_cos7-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'YOLOX_outputs/yolox_x_mix_det/track_vis/2022_05_03_06_33_26/palace.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:10.97, start: 0.000000, bitrate: 20198 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 20196 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> vp9 (libvpx-vp9))
# Press [q] to stop, [?] for help
# [libvpx-vp9 @ 0x11a4d2580] v1.7.0
# Output #0, webm, to 'out.webm':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: vp9 (libvpx-vp9), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 200 kb/s, 30 fps, 1k tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libvpx-vp9
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  329 fps=2.1 q=0.0 Lsize=     481kB time=00:00:10.93 bitrate= 360.4kbits/s speed=0.0695x
# video:478kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.644510%

# %%
# == Display results ==
from IPython.display import HTML
from base64 import b64encode

video_path = 'out.webm'

mp4 = open(video_path, "rb").read()
data_url = "data:video/webm;base64," + b64encode(mp4).decode()
HTML(f"""
<video width=600 controls>
      <source src="{data_url}" type="video/webm">
</video>
""")
# Out:
# <video width=600 controls>
#       <source src="data:video/webm;base64,..." type="video/webm">
# </video>
